# %% [markdown]
# # Load Necessary lib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Bacis gragh

# %% [markdown]
# # Line Chart Gragh

# %%
#x=[]قيم , #y=[] 
#plot() دالة للرسم الخط
x=[0,1,2,3,5]
y=[0,2,4,6,10]

#resize figure
#تعديل حجم الصورة 
plt.figure(figsize=(5,3), dpi=100)
#كتابة العنوان 
plt.title("our first gragh")#, fontdict=('fontname:comis san MS',' fontsize':24))
 #,fontdict=('fontname:NAME OF FONT ',' fontsize':SIZE OF FONT))
#, fontdict=('fontname:comis san MS',' fontsize':24))لتعديل الخط وحجمه
# xعنوان محور 
plt.xlabel("x aixs")
# yعنوان محور
plt.ylabel("y aixs")

#plt.plot(x,y ,label='2x'يدل على , color='red' لون الخط)

#plt.plot(x,y ,label='2x', color='red', linewidth=2,marker='.',markersize=10,markeredgecolor='blue')

#اختصارات لي color , marker,makersize ,linewidth=2
plt.plot(x,y,'b^--' ,label='2x')
#لضافة قيم جديدة numpy اضافة استخدام مكتبة 
x2=np.arange(0,4.5,0.5)

#استخام الاختار لون 

#linewidth=2,marker='.'اضافة نقاط,markersize=10,حجم النقاط   markeredgecolor='blue لون النقاط
plt.plot(x2[:6],x2[:6]**2,'r',label='x^2')
plt.plot(x2[5:],x2[5:]**2,'r--')
#plt.plot(x2,x2**2,'r',label='x^2')

#تشغيل label
plt.legend()

plt.xticks([0,1,2,3,4,5]) # falot to int تغير الارقام من
#plt.yticks([0,2,4,6,8,10])

#حفظ الملف 
plt.savefig("mygragh.png",dpi=100)
#اظهار في الشاشة
plt.show()

# %%
plt.plot(x2[:6],x2[:6]**2,'r',label='x^2')
plt.plot(x2[5:],x2[5:]**2,'r--')
#اضافة استخدام مكتبة numpy واستخدام الدالة arange(0,4.5,0.5) a لضرب القيم في 2 من 0 الى6  ومن5الى اخر رقم

# %% [markdown]
# # Bar Chart Gragh

# %%
#labals القيم في محور س
labals=['A','B','C']
#valubes القيم في محور ص
valubes=[1,4,2]
#use fnction.bar() for show bar gragh
#plt.bar(x,y)
bar=plt.bar(labals,valubes)
#use funtion.set_hatch('/', *, 0)  لرسم لى الاعمدة 
#bar[0].set_hatch('/')
#bar[1].set_hatch('*')
#bar[2].set_hatch("o")

#use pattern for darw .set_hatch('/', *, 0) with out recurrence  
#pattern =['/','*','o']
#for bar in bar:
    #bar.set_hatch(pattern.pop(0)) 

plt.figure(figsize=(4,3), dpi=100)


plt.show()

# %%
x1=[0,2,3,4,5]
y1=[0,4,6,8,10]

plt.title ("line g")
plt.plot(x1,y1 , label='x3',linewidth=2,marker='.',markersize=10,markeredgecolor='g')
plt.xlabel("x aixs")
plt.ylabel("y aixs")

plt.legend()
plt.show()

# %%
s=['M','F']
plt.title ("Gander")
Vaubles=[50/100,45/100 ]
plt.bar(labels,Vaubles,color="y" , label='Gander')
plt.legend()
plt.show()
